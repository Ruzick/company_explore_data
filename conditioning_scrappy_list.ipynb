# %%
import pandas as pd

# %%
a=pd.read_csv('glassdoor_company_links.txt', sep=';',  header=None)
# pd.read_csv('glassdoor_company_links.txt', header= None)

# %%
a.columns=['company', 'site']

# %%
a.head(20)
# Out:
#                      company  \
# 0                    Walmart
# 1                     Amazon
# 2                Exxon Mobil
# 3                      Apple
# 4                 CVS Health
# 5         Berkshire Hathaway
# 6         UnitedHealth Group
# 7                   McKesson
# 8                       AT&T
# 9          AmerisourceBergen
# 10                  Alphabet
# 11                Ford Motor
# 12                     Cigna
# 13          Costco Wholesale
# 14                   Chevron
# 15           Cardinal Health
# 16            JPMorgan Chase
# 17            General Motors
# 18  Walgreens Boots Alliance
# 19    Verizon Communications
#
#                                                  site
# 0   https://www.glassdoor.com/Overview/Working-at-...
# 1   https://www.glassdoor.com/Overview/Working-at-...
# 2   https://www.glassdoor.com/Overview/Working-at-...
# 3   https://www.glassdoor.com/Overview/Working-at-...
# 4   https://www.glassdoor.com/Overview/Working-at-...
# ...

# %%
list(a['company'])
# Out:
# ['Walmart',
#  'Amazon',
#  'Exxon Mobil',
#  'Apple',
#  'CVS Health',
#  'Berkshire Hathaway',
#  'UnitedHealth Group',
#  'McKesson',
#  'AT&T',
#  'AmerisourceBergen',
#  'Alphabet',
#  'Ford Motor',
#  'Cigna',
#  'Costco Wholesale',
#  'Chevron',
#  'Cardinal Health',
#  'JPMorgan Chase',
#  'General Motors',
#  'Walgreens Boots Alliance',
#  'Verizon Communications',
#  'Microsoft',
#  'Marathon Petroleum',
#  'Kroger',
#  'Fannie Mae',
#  'Bank of America',
#  'Home Depot',
#  'Phillips 66',
#  'Comcast',
#  'Anthem',
#  'Wells Fargo',
#  'Valero Energy',
#  'General Electric',
#  'Dell Technologies',
#  'Johnson & Johnson',
#  'State Farm Insurance',
#  'Target',
#  'IBM',
#  'Raytheon Technologies',
#  'Boeing',
#  'Freddie Mac',
#  'Centene',
#  'UPS',
#  "Lowe's",
#  'Intel',
#  'FedEx',
#  'MetLife',
#  'Walt Disney',
#  'Procter & Gamble',
#  'PepsiCo',
#  'Humana',
#  'Prudential Financial (U.S.)',
#  'Archer Daniels Midland',
#  'Albertsons',
#  'Sysco',
# ...

# %%
a = a.replace(r' ','-', regex=True) 
# a=a.replace(r'.','_', regex=True)

# %%
# a=a.set_index('company')
a['company'] = a.company.map(str) + ".csv"

# %%
a.head(20)
# Out:
#                          company  \
# 0                    Walmart.csv
# 1                     Amazon.csv
# 2                Exxon-Mobil.csv
# 3                      Apple.csv
# 4                 CVS-Health.csv
# 5         Berkshire-Hathaway.csv
# 6         UnitedHealth-Group.csv
# 7                   McKesson.csv
# 8                       AT&T.csv
# 9          AmerisourceBergen.csv
# 10                  Alphabet.csv
# 11                Ford-Motor.csv
# 12                     Cigna.csv
# 13          Costco-Wholesale.csv
# 14                   Chevron.csv
# 15           Cardinal-Health.csv
# 16            JPMorgan-Chase.csv
# 17            General-Motors.csv
# 18  Walgreens-Boots-Alliance.csv
# 19    Verizon-Communications.csv
#
#                                                  site
# 0   https://www.glassdoor.com/Overview/Working-at-...
# 1   https://www.glassdoor.com/Overview/Working-at-...
# 2   https://www.glassdoor.com/Overview/Working-at-...
# ...

# %%
a=a.set_index('company')

# %%
a
# Out:
#                                                                             site
# company
# Walmart.csv                    https://www.glassdoor.com/Overview/Working-at-...
# Amazon.csv                     https://www.glassdoor.com/Overview/Working-at-...
# Exxon-Mobil.csv                https://www.glassdoor.com/Overview/Working-at-...
# Apple.csv                      https://www.glassdoor.com/Overview/Working-at-...
# CVS-Health.csv                 https://www.glassdoor.com/Overview/Working-at-...
# ...                                                                          ...
# Mr.-Cooper-Group.csv           https://www.glassdoor.com/Overview/Working-at-...
# Herc-Holdings.csv              https://www.glassdoor.com/Overview/Working-at-...
# Healthpeak-Properties.csv      https://www.glassdoor.com/Overview/Working-at-...
# SPX-FLOW.csv                   https://www.glassdoor.com/Overview/Working-at-...
# ...

# %%
droplist=['DuPont.csv', 'Emerson-Electric.csv' ,'WestRock.csv','CDW.csv','Sherwin-Williams.csv','PayPal-Holdings.csv','D.R.-Horton.csv','HollyFrontier.csv','Tenneco.csv','BD.csv','EOG-Resources.csv','Kimberly-Clark.csv','Tenet-Healthcare.csv','CarMax.csv','NextEra-Energy.csv','Genuine-Parts.csv','Synchrony-Financial.csv','Performance-Food-Group.csv','Altria-Group.csv','Lear.csv','AECOM.csv','Hartford-Financial-Services-Group.csv','PNC-Financial-Services-Group.csv','Rite-Aid.csv','Southwest-Airlines.csv','Gilead-Sciences.csv','Amgen.csv','CBRE-Group.csv','Union-Pacific.csv','Occidental-Petroleum.csv','Lennar.csv','Aflac.csv','Eli-Lilly.csv','International-Paper.csv','Lumen-Technologies.csv','Halliburton.csv','Nucor.csv','Broadcom.csv','Visa.csv','Penske-Automotive-Group.csv','Micron-Technology.csv','United-Natural-Foods.csv','Cummins.csv','Dollar-Tree.csv','Synnex.csv','Baker-Hughes.csv','NGL-Energy-Partners.csv','TIAA.csv','Deere.csv','StoneX-Group.csv','CHS.csv','Philip-Morris-International.csv','U.S.-Bancorp.csv','Starbucks.csv','Bristol-Myers-Squibb.csv','Thermo-Fisher-Scientific.csv',"Macy's.csv",'Jabil.csv','Qualcomm.csv','Kraft-Heinz.csv','Duke-Energy.csv','Tesla.csv','PBF-Energy.csv','Plains-GP-Holdings.csv','Enterprise-Products-Partners.csv','Southern-Company.csv','AutoNation.csv','DXC-Technology.csv',"McDonald's.csv",'Marriott-International.csv','ManpowerGroup.csv','Bank-of-New-York-Mellon.csv','Danaher.csv','Whirlpool.csv','Netflix.csv','Avnet.csv',"Kohl's.csv",'Paccar.csv','Delta-Air-Lines.csv','ConocoPhillips.csv','USAA.csv','Exelon.csv','Northrop-Grumman.csv','Capital-One-Financial.csv','AbbVie.csv','Northwestern-Mutual.csv','3M.csv','Abbott-Laboratories.csv','Travelers-Cos..csv','Raytheon.csv','US-Foods-Holding.csv','Mondelez-International.csv','Honeywell-International.csv','World-Fuel-Services.csv','Tech-Data.csv','Massachusetts-Mutual-Life.csv','Coca-Cola.csv','TJX.csv','Allstate.csv','Best-Buy.csv','United-Airlines-Holdings.csv','Liberty-Mutual-Insurance-Group.csv', 'Apple.csv', 'Amazon.csv', 'McKesson.csv','AT&T.csv','Alphabet.csv', 'AmerisourceBergen.csv','Cigna.csv', 'Chevron.csv', 'Kroger.csv', 'Anthem.csv' , 'Comcast.csv', 'Phillips-66.csv', 'Home-Depot.csv', 'Bank-of-America.csv', 'Fannie-Mae.csv', 'Marathon-Petroleum.csv','Microsoft.csv','Verizon-Communications.csv','General-Motors.csv','Cardinal-Health.csv', 'Costco-Wholesale.csv', 'Ford-Motor.csv','UnitedHealth-Group.csv','Berkshire-Hathaway.csv','CVS-Health.csv','Exxon-Mobil.csv','MetLife.csv','FedEx.csv',"Lowe's.csv",'UPS.csv','Centene.csv','Freddie-Mac.csv','Raytheon-Technologies.csv','IBM.csv', 'State-Farm-Insurance.csv','Dell-Technologies.csv','General-Electric.csv', 'Valero-Energy.csv','Wells-Fargo.csv','Walgreens-Boots-Alliance.csv','JPMorgan-Chase.csv','Walmart.csv','Johnson-&-Johnson.csv','Target.csv','Boeing.csv', 'Intel.csv','Walt-Disney.csv','Procter-&-Gamble.csv','PepsiCo.csv','Humana.csv','Prudential-Financial-(U.S.).csv','Archer-Daniels-Midland.csv','Albertsons.csv', 'Sysco.csv','Lockheed-Martin.csv','Energy-Transfer.csv','Goldman-Sachs-Group.csv' ,'Morgan-Stanley.csv','Caterpillar.csv', 'Cisco-Systems.csv','HP.csv','Pfizer.csv','American-Express.csv','Dow.csv', 'Tyson-Foods.csv', 'Oracle.csv','General-Dynamics.csv','Nike.csv','Progressive.csv','Publix-Super-Markets.csv','Hewlett-Packard-Enterprise.csv','Arrow-Electronics.csv','ViacomCBS.csv','Dollar-General.csv','HCA-Healthcare.csv', 'American-International-Group.csv', 'Merck.csv' , 'American-Airlines-Group.csv', 'Charter-Communications.csv','New-York-Life-Insurance.csv','Nationwide.csv']

# %%
len(droplist)
# Out:
# 183

# %%
a=a.drop(droplist)

# %%
len(a)
# Out:
# 803

# %%
d=a[:-486]

# %%
# a = a.replace(r'\n','', regex=True)

# %%
d.head(4)
# Out:
#                                                                            site
# company
# Jones-Lang-LaSalle-(JLL).csv  https://www.glassdoor.com/Overview/Working-at-...
# Fluor.csv                     https://www.glassdoor.com/Overview/Working-at-...
# Lincoln-National.csv          https://www.glassdoor.com/Overview/Working-at-...
# Salesforce.csv                https://www.glassdoor.com/Overview/Working-at-...

# %%
d.reset_index()
# Out:
#                           company  \
# 0    Jones-Lang-LaSalle-(JLL).csv
# 1                       Fluor.csv
# 2            Lincoln-National.csv
# 3                  Salesforce.csv
# 4                  Mastercard.csv
# ..                            ...
# 312    Sprouts-Farmers-Market.csv
# 313    LPL-Financial-Holdings.csv
# 314             T.-Rowe-Price.csv
# 315                Yum-Brands.csv
# 316    Chipotle-Mexican-Grill.csv
#
#                                                   site
# 0    https://www.glassdoor.com/Overview/Working-at-...
# 1    https://www.glassdoor.com/Overview/Working-at-...
# 2    https://www.glassdoor.com/Overview/Working-at-...
# 3    https://www.glassdoor.com/Overview/Working-at-...
# 4    https://www.glassdoor.com/Overview/Working-at-...
# ..                                                 ...
# 312  https://www.glassdoor.com/Overview/Working-at-...
# 313  https://www.glassdoor.com/Overview/Working-at-...
# ...

# %%
d.to_csv(r'le.txt', sep=';', header=None)

# %%
b=pd.read_csv('le.txt', header=None, sep=';')

# %%
b
# Out:
#                                 0  \
# 0                     Walmart.csv
# 1              JPMorgan-Chase.csv
# 2    Walgreens-Boots-Alliance.csv
# 3                 Wells-Fargo.csv
# 4               Valero-Energy.csv
# ..                            ...
# 469    Sprouts-Farmers-Market.csv
# 470    LPL-Financial-Holdings.csv
# 471             T.-Rowe-Price.csv
# 472                Yum-Brands.csv
# 473    Chipotle-Mexican-Grill.csv
#
#                                                      1
# 0    https://www.glassdoor.com/Overview/Working-at-...
# 1    https://www.glassdoor.com/Overview/Working-at-...
# 2    https://www.glassdoor.com/Overview/Working-at-...
# 3    https://www.glassdoor.com/Overview/Working-at-...
# 4    https://www.glassdoor.com/Overview/Working-at-...
# ..                                                 ...
# 469  https://www.glassdoor.com/Overview/Working-at-...
# 470  https://www.glassdoor.com/Overview/Working-at-...
# ...
