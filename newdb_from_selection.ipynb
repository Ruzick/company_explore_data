# %%
import pandas as pd

# %%
 alist=['3M',
 'AECOM',
 'AT&T',
 'AbbVie',
 'Abbott Laboratories',
 'Aflac',
 'Albertsons',
 'Allstate']

# %%
db=pd.read_csv('clusters.csv')

# %%
makedb=pd.DataFrame(alist)

# %%
makedb=makedb.rename(columns={0:'company'})

# %%
makedb=makedb.set_index('company')

# %%
makedb.head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [3M, AECOM]

# %%
db.head(5)
# Out:
#                company  balanc  discount  divers  food  free coff  free lunch  \
# 0                   3M      33        10      39    -2         -1           0
# 1                AECOM       0         0       0    -1          0           0
# 2                 AT&T     -20        22      10    -1          0           0
# 3               AbbVie      27         0     -19     2          0           0
# 4  Abbott Laboratories       7         3      -1     2          2           2
#
#    gym  health  ice cream  ...  sign bonus  stock option  stress  \
# 0   -1       9          0  ...           0             3      -3
# 1    0       0          0  ...           0             0       0
# 2    0      12          0  ...           0             0     -41
# 3    3       2          0  ...           0            -2     -16
# 4    0      36          0  ...           0             3     -19
#
#    student loan pay  surf  vacat  women  work environ  work home  yoga
# ...

# %%
t=pd.merge(makedb, db, how="left", on='company')

# %%
t
# Out:
#                company  balanc  discount  divers  food  free coff  free lunch  \
# 0                   3M      33        10      39    -2         -1           0
# 1                AECOM       0         0       0    -1          0           0
# 2                 AT&T     -20        22      10    -1          0           0
# 3               AbbVie      27         0     -19     2          0           0
# 4  Abbott Laboratories       7         3      -1     2          2           2
# 5                Aflac      20         3       3     2          0           0
# 6           Albertsons      -1         8      -2     2          0           0
# 7             Allstate      50         0      -1     2          0           0
#
#    gym  health  ice cream  ...  sign bonus  stock option  stress  \
# 0   -1       9          0  ...           0             3      -3
# 1    0       0          0  ...           0             0       0
# 2    0      12          0  ...           0             0     -41
# ...
